# %%
import whitebox
from whitebox import WhiteboxTools

# Initialize the WhiteboxTools object
wbt = WhiteboxTools()

# Path to your input DTM file
input_dtm = r"C:\Users\artur\OneDrive\Documentos\Sil e Mari\mdt_rec.tif"

# Path for the output file
output_dtm = r"C:\Users\artur\OneDrive\Área de Trabalho\Sil e Mari\mdt_rec_wb_breach_depressions.tif"

# Run the breach depressions tool
wbt.breach_depressions(
    dem=input_dtm,
    output=output_dtm,
    max_depth=None,  # Optionally set a maximum depth of depressions to breach
    max_length=None, # Optionally set a maximum length of depressions to breach
    flat_increment=None, # Optionally set an elevation increment for flats
    fill_pits=False # Optionally fill pits after breaching
)

print("Depressions breached successfully!")
# Out:
# .\whitebox_tools.exe --run="BreachDepressions" --dem='C:\Users\artur\OneDrive\Documentos\Sil e Mari\mdt_rec.tif' --output='C:\Users\artur\OneDrive\Área de Trabalho\Sil e Mari\mdt_rec_wb_breach_depressions.tif' -v --compress_rasters=False
#
# ********************************
# * Welcome to BreachDepressions *
# * Powered by WhiteboxTools     *
# * www.whiteboxgeo.com          *
# ********************************
# Reading data...
# Progress: 0%
# Progress: 1%
# Progress: 2%
# Progress: 3%
# Progress: 4%
# Progress: 5%
# Progress: 6%
# Progress: 7%
# Progress: 8%
# Progress: 9%
# Progress: 10%
# Progress: 11%
# Progress: 12%
# Progress: 13%
# Progress: 14%
# Progress: 15%
# Progress: 16%
# Progress: 17%
# Progress: 18%
# Progress: 19%
# Progress: 20%
# Progress: 21%
# Progress: 22%
# Progress: 23%
# Progress: 24%
# Progress: 25%
# Progress: 26%
# Progress: 27%
# Progress: 28%
# Progress: 29%
# Progress: 30%
# Progress: 31%
# Progress: 32%
# Progress: 33%
# Progress: 34%
# ...
